# %%
#%%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import main

df = await main.get_dataframe()
display(df)
# Out:
#                                  nation_official_name    currency_name  \
# 0                                 Republic of Finland             Euro
# 1                                   Kingdom of Sweden    Swedish krona
# 2                               Svalbard og Jan Mayen            krone
# 3                                  Republic of Latvia             Euro
# 4                                         Isle of Man    British pound
# 5                                  Kingdom of Denmark     Danish krone
# 6                                       Faroe Islands     Danish krone
# 7                                 Bailiwick of Jersey    British pound
# 8                                       Åland Islands             Euro
# 9                                             Iceland  Icelandic króna
# 10                              Republic of Lithuania             Euro
# 11                              Bailiwick of Guernsey    British pound
# ...
